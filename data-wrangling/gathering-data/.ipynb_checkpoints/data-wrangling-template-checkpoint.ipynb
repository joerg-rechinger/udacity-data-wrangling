# %% [markdown]
# # Data Wrangling Template

# %% [markdown]
# ## Gather

# %%
from bs4 import BeautifulSoup
import os
import pandas as pd

# %%
df = pd.read_csv('bestofrt.tsv',sep='\t')

# %%
df.head()
# Out:
#    ranking  critic_score                      title  number_of_critic_ratings
# 0        1            99    The Wizard of Oz (1939)                       110
# 1        2           100        Citizen Kane (1941)                        75
# 2        3           100       The Third Man (1949)                        77
# 3        4            99             Get Out (2017)                       282
# 4        5            97  Mad Max: Fury Road (2015)                       370

# %%
#import zipfile

# %%
#with zipfile.ZipFile('rt-html.zip', 'r') as myzip:
    #myzip.extractall()

# %%
with open('rt_html/12_years_a_slave.html') as file:
    soup = BeautifulSoup(file, "lxml")

# %%
#BeautifulSoup
# List of dictionaries to build file by file and later convert to a DataFrame
df_list = []
folder = 'rt_html'
for movie_html in os.listdir(folder):
    with open(os.path.join(folder, movie_html)) as file:
        # Your code here
        soup = BeautifulSoup(file)
        print(soup)
        break
        title = soup.find('title').contents[0][:-len(' - Rotten Tomatoes')]
        audience_score = soup.find('div', class_='audience-score meter').find('span').contents[0][:-1]
        num_audience_ratings = soup.find('div', class_='audience-info').find_all('div')[-1].contents[-1].split()[0].replace(',','')
        # Note: a correct implementation may take ~15 seconds to run
        
        
        # Append to list of dictionaries
        df_list.append({'title': title,
                        'audience_score': int(audience_score),
                        'number_of_audience_ratings': int(num_audience_ratings)})
df = pd.DataFrame(df_list, columns = ['title', 'audience_score', 'number_of_audience_ratings'])
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-32-c52c865909d6> in <module>
#       6     with open(os.path.join(folder, movie_html)) as file:
#       7         # Your code here
# ----> 8         soup = BeautifulSoup(file, from_encoding='utf-8')
#       9         print(soup)
#      10         break
#
# /Users/python/anaconda3/lib/python3.7/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     242
#     243         if hasattr(markup, 'read'):        # It's a file-type object.
# --> 244             markup = markup.read()
#     245         elif len(markup) <= 256 and (
#     246                 (isinstance(markup, bytes) and not b'<' in markup)
#
# /Users/python/anaconda3/lib/python3.7/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x86 in position 27: invalid start byte

# %% [markdown]
# Solution Test to check if code is correct:

# %%
df_solution = pd.read_pickle('df_solution.pkl')
df.sort_values('title', inplace = True)
df.reset_index(inplace = True, drop = True)
df_solution.sort_values('title', inplace = True)
df_solution.reset_index(inplace = True, drop = True)
pd.testing.assert_frame_equal(df, df_solution)

# %%
df_new = pd.read_csv('rt_html.csv')
df_new.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df_new
# Out:
#                                                 title  audience_score  \
# 0                           A Hard Day's Night (1964)              89
# 1                                        Logan (2017)              91
# 2                              Rosemary's Baby (1968)              87
# 3                            On the Waterfront (1954)              95
# 4                                    Open City (1946)              92
# 5                                      Arrival (2016)              82
# 6         Seven Samurai (Shichinin no Samurai) (1956)              97
# 7                                    Toy Story (1995)              92
# 8                             The Wizard of Oz (1939)              89
# 9                                        Alien (1979)              94
# 10             Snow White and the Seven Dwarfs (1937)              78
# 11  The Battle of Algiers (La Battaglia di Algeri)...              95
# 12                                    Zootopia (2016)              92
# 13             12 Angry Men (Twelve Angry Men) (1957)              97
# 14                          The Maltese Falcon (1941)              91
# 15                                 Man on Wire (2008)              87
# 16                                        Jaws (1975)              90
# 17                                   Spotlight (2015)              93
# 18                                  La La Land (2016)              82
# 19                                     Boyhood (2014)              81
# 20                The Adventures of Robin Hood (1938)              89
# 21                       It Happened One Night (1934)              93
# 22                             The Dark Knight (2008)              94
# 23                              Apocalypse Now (1979)              94
# 24                      The Godfather, Part II (1974)              97
# 25                         Battleship Potemkin (1925)              85
# 26                                   High Noon (1952)              89
# 27                      The Philadelphia Story (1940)              93
# 28  Nosferatu, a Symphony of Horror (Nosferatu, ei...              87
# 29                       Manchester by the Sea (2016)              77
# ..                                                ...             ...
# 70                                 Toy Story 2 (1999)              86
# 71                                     Dunkirk (2017)              82
# 72                                   Repulsion (1965)              87
# 73                   The Bride of Frankenstein (1935)              87
# 74        Army of Shadows (L'Armée des ombres) (1969)              94
# 75                                    Brooklyn (2015)              87
# 76                                The Big Sick (2017)              90
# 77                                       Selma (2015)              86
# 78                               All About Eve (1950)              94
# 79                                 Rear Window (1954)              95
# 80                                   Pinocchio (1940)              72
# 81                                  Casablanca (1942)              95
# 82                               The Third Man (1949)              93
# 83                           L.A. Confidential (1997)              94
# 84                               Touch of Evil (1958)              92
# 85                                The Babadook (2014)              72
# 86                         Singin' in the Rain (1952)              95
# 87                                Frankenstein (1931)              87
# 88  Dr. Strangelove Or How I Learned to Stop Worry...              94
# 89                         The Grapes of Wrath (1940)              88
# 90       Bicycle Thieves (Ladri di biciclette) (1949)              94
# 91            The Treasure of the Sierra Madre (1948)              93
# 92                                    Rashômon (1951)              93
# 93                                Citizen Kane (1941)              90
# 94                          Hell or High Water (2016)              88
# 95                                           M (1931)              95
# 96                                  Metropolis (1927)              92
# 97      The 400 Blows (Les Quatre cents coups) (1959)              94
# 98                           The Wages of Fear (1953)              95
# 99                             The Jungle Book (2016)              86
#
#     number_of_audience_ratings
# 0                        50067
# 1                        86540
# 2                        72669
# 3                        51664
# 4                         6128
# 5                        78740
# 6                        90049
# 7                      1107731
# 8                       874425
# 9                       457186
# 10                      469510
# 11                       14267
# 12                       98633
# 13                      103672
# 14                       57268
# 15                       29827
# 16                      942217
# 17                       68142
# 18                       67325
# 19                       88478
# 20                       33584
# 21                       33106
# 22                     1827436
# 23                      284606
# 24                      409574
# 25                       18709
# 26                       25065
# 27                       46810
# 28                       47463
# 29                       48189
# ..                         ...
# 70                      998186
# 71                       53555
# 72                       18655
# 73                       24471
# 74                        7011
# 75                       45763
# 76                       23391
# 77                       60533
# 78                       44564
# 79                      149458
# 80                      278682
# 81                      355952
# 82                       53081
# 83                      149772
# 84                       30867
# 85                       37024
# 86                      137643
# 87                       41140
# 88                      208215
# 89                       23954
# 90                       33723
# 91                       25627
# 92                       47657
# 93                      157274
# 94                       37738
# 95                       35778
# 96                       62018
# 97                       38368
# 98                        8536
# 99                       92856
#
# [100 rows x 3 columns]

# %% [markdown]
# ## Assess

# %% [markdown]
# ## Clean

# %% [markdown]
# #### Define

# %% [markdown]
# #### Code

# %% [markdown]
# #### Test
